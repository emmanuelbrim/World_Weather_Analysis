# %%
import pandas as pd
import numpy as np
from citipy import citipy

# %%
#Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs=zip(lats,lngs)
cordinates=list(lats_lngs)

# %%
#Get the nearest city using the citipy module.
# Create a list for holding the cities.
cities=[]

for i in cordinates:
    city= citipy.nearest_city(i[0],i[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        

len(cities)
# Out:
# 760

# %%
# Import the time library and the datetime module from the datetime library 
import time
import requests
from config import weather_api_key
url="http://api.openweathermap.org/data/2.5/weather?"
city_data=[]

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "appid=" + weather_api_key + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_descrip = city_weather["weather"][0]["description"]
         # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country":city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_weather_descrip})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | castro
# Processing Record 3 of Set 1 | torbay
# Processing Record 4 of Set 1 | lebu
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | burica
# City not found. Skipping...
# Processing Record 8 of Set 1 | hutchinson
# Processing Record 9 of Set 1 | nome
# Processing Record 10 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 1 | tasiilaq
# Processing Record 12 of Set 1 | nanortalik
# Processing Record 13 of Set 1 | port-gentil
# Processing Record 14 of Set 1 | mortka
# Processing Record 15 of Set 1 | padang
# Processing Record 16 of Set 1 | san jose
# Processing Record 17 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 1 | lata
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | qaanaaq
# Processing Record 21 of Set 1 | przhevalskoye
# Processing Record 22 of Set 1 | manzil tamim
# City not found. Skipping...
# Processing Record 23 of Set 1 | mongu
# Processing Record 24 of Set 1 | saint george
# Processing Record 25 of Set 1 | vao
# Processing Record 26 of Set 1 | gimli
# Processing Record 27 of Set 1 | mount holly
# Processing Record 28 of Set 1 | dandong
# Processing Record 29 of Set 1 | victoria
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | carnarvon
# Processing Record 32 of Set 1 | severo-kurilsk
# Processing Record 33 of Set 1 | port alfred
# Processing Record 34 of Set 1 | kapaa
# Processing Record 35 of Set 1 | hobart
# Processing Record 36 of Set 1 | igbaras
# Processing Record 37 of Set 1 | lompoc
# Processing Record 38 of Set 1 | avera
# Processing Record 39 of Set 1 | port elizabeth
# Processing Record 40 of Set 1 | saskylakh
# Processing Record 41 of Set 1 | cherskiy
# Processing Record 42 of Set 1 | rantauprapat
# Processing Record 43 of Set 1 | dunedin
# Processing Record 44 of Set 1 | humaita
# Processing Record 45 of Set 1 | constitucion
# Processing Record 46 of Set 1 | puerto princesa
# Processing Record 47 of Set 1 | kavieng
# Processing Record 48 of Set 1 | busselton
# Processing Record 49 of Set 1 | pisco
# Processing Record 50 of Set 1 | bulawayo
# Processing Record 1 of Set 2 | ribeira grande
# Processing Record 2 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 2 | chuy
# Processing Record 4 of Set 2 | berlevag
# Processing Record 5 of Set 2 | yellowknife
# Processing Record 6 of Set 2 | dicabisagan
# Processing Record 7 of Set 2 | chokurdakh
# Processing Record 8 of Set 2 | hithadhoo
# Processing Record 9 of Set 2 | cape town
# Processing Record 10 of Set 2 | southbridge
# Processing Record 11 of Set 2 | puerto ayora
# Processing Record 12 of Set 2 | mar del plata
# Processing Record 13 of Set 2 | beloha
# Processing Record 14 of Set 2 | cururupu
# Processing Record 15 of Set 2 | novobiryusinskiy
# Processing Record 16 of Set 2 | saint-philippe
# Processing Record 17 of Set 2 | talcahuano
# Processing Record 18 of Set 2 | grindavik
# Processing Record 19 of Set 2 | ambilobe
# Processing Record 20 of Set 2 | ancud
# Processing Record 21 of Set 2 | port hedland
# Processing Record 22 of Set 2 | fortuna
# Processing Record 23 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 25 of Set 2 | hermanus
# Processing Record 26 of Set 2 | anadyr
# Processing Record 27 of Set 2 | henties bay
# Processing Record 28 of Set 2 | barrow
# Processing Record 29 of Set 2 | upernavik
# Processing Record 30 of Set 2 | agirish
# Processing Record 31 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 2 | albany
# Processing Record 33 of Set 2 | dharan
# Processing Record 34 of Set 2 | dzaoudzi
# Processing Record 35 of Set 2 | mataura
# Processing Record 36 of Set 2 | pokhara
# Processing Record 37 of Set 2 | chulman
# Processing Record 38 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 2 | cabo san lucas
# Processing Record 40 of Set 2 | vestmanna
# Processing Record 41 of Set 2 | norman wells
# Processing Record 42 of Set 2 | klaksvik
# Processing Record 43 of Set 2 | bairiki
# Processing Record 44 of Set 2 | san onofre
# Processing Record 45 of Set 2 | hobyo
# Processing Record 46 of Set 2 | vaini
# Processing Record 47 of Set 2 | cidreira
# Processing Record 48 of Set 2 | arraial do cabo
# Processing Record 49 of Set 2 | guymon
# Processing Record 50 of Set 2 | shimoda
# Processing Record 1 of Set 3 | plettenberg bay
# Processing Record 2 of Set 3 | samarai
# Processing Record 3 of Set 3 | mount gambier
# Processing Record 4 of Set 3 | geraldton
# Processing Record 5 of Set 3 | east london
# Processing Record 6 of Set 3 | yabrud
# Processing Record 7 of Set 3 | nikolskoye
# Processing Record 8 of Set 3 | maxixe
# Processing Record 9 of Set 3 | butaritari
# Processing Record 10 of Set 3 | thompson
# Processing Record 11 of Set 3 | vila velha
# Processing Record 12 of Set 3 | narsaq
# Processing Record 13 of Set 3 | seoul
# Processing Record 14 of Set 3 | zinder
# Processing Record 15 of Set 3 | bredasdorp
# Processing Record 16 of Set 3 | los llanos de aridane
# Processing Record 17 of Set 3 | gharghoda
# Processing Record 18 of Set 3 | agadez
# Processing Record 19 of Set 3 | zyryanka
# Processing Record 20 of Set 3 | saldanha
# Processing Record 21 of Set 3 | ilulissat
# Processing Record 22 of Set 3 | saint-pierre
# Processing Record 23 of Set 3 | pangnirtung
# Processing Record 24 of Set 3 | shenjiamen
# Processing Record 25 of Set 3 | astara
# Processing Record 26 of Set 3 | oppdal
# Processing Record 27 of Set 3 | diego de almagro
# Processing Record 28 of Set 3 | makat
# Processing Record 29 of Set 3 | bubaque
# Processing Record 30 of Set 3 | hilo
# Processing Record 31 of Set 3 | lavrentiya
# Processing Record 32 of Set 3 | sao filipe
# Processing Record 33 of Set 3 | trairi
# Processing Record 34 of Set 3 | avarua
# Processing Record 35 of Set 3 | kalangala
# Processing Record 36 of Set 3 | northam
# Processing Record 37 of Set 3 | taksimo
# Processing Record 38 of Set 3 | opuwo
# Processing Record 39 of Set 3 | sur
# Processing Record 40 of Set 3 | whitehorse
# Processing Record 41 of Set 3 | kodiak
# Processing Record 42 of Set 3 | victor harbor
# Processing Record 43 of Set 3 | miraflores
# Processing Record 44 of Set 3 | dudinka
# Processing Record 45 of Set 3 | moussoro
# Processing Record 46 of Set 3 | arman
# Processing Record 47 of Set 3 | ixtapa
# Processing Record 48 of Set 3 | san rafael
# Processing Record 49 of Set 3 | husavik
# Processing Record 50 of Set 3 | leningradskiy
# Processing Record 1 of Set 4 | dalvik
# Processing Record 2 of Set 4 | virginia beach
# Processing Record 3 of Set 4 | belyy yar
# Processing Record 4 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 4 | gladstone
# Processing Record 6 of Set 4 | tuktoyaktuk
# Processing Record 7 of Set 4 | new norfolk
# Processing Record 8 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 4 | dali
# Processing Record 10 of Set 4 | mineros
# Processing Record 11 of Set 4 | kharp
# Processing Record 12 of Set 4 | colesberg
# Processing Record 13 of Set 4 | tiksi
# Processing Record 14 of Set 4 | kieta
# Processing Record 15 of Set 4 | madison heights
# Processing Record 16 of Set 4 | nybro
# Processing Record 17 of Set 4 | port hardy
# Processing Record 18 of Set 4 | jucuaran
# Processing Record 19 of Set 4 | ushtobe
# Processing Record 20 of Set 4 | kaeo
# Processing Record 21 of Set 4 | tongliao
# Processing Record 22 of Set 4 | charters towers
# Processing Record 23 of Set 4 | isla mujeres
# Processing Record 24 of Set 4 | borovskoy
# Processing Record 25 of Set 4 | nambutalai
# Processing Record 26 of Set 4 | jamestown
# Processing Record 27 of Set 4 | aswan
# Processing Record 28 of Set 4 | mosquera
# Processing Record 29 of Set 4 | jardim
# Processing Record 30 of Set 4 | fort nelson
# Processing Record 31 of Set 4 | ponta do sol
# Processing Record 32 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 4 | dhanwar
# Processing Record 34 of Set 4 | port lincoln
# Processing Record 35 of Set 4 | kahului
# Processing Record 36 of Set 4 | iquitos
# Processing Record 37 of Set 4 | sola
# Processing Record 38 of Set 4 | mumford
# Processing Record 39 of Set 4 | muisne
# Processing Record 40 of Set 4 | boyolangu
# Processing Record 41 of Set 4 | rodnykove
# Processing Record 42 of Set 4 | abu kamal
# Processing Record 43 of Set 4 | manadhoo
# Processing Record 44 of Set 4 | kloulklubed
# Processing Record 45 of Set 4 | puerto colombia
# Processing Record 46 of Set 4 | monte alegre
# Processing Record 47 of Set 4 | olinda
# Processing Record 48 of Set 4 | talnakh
# Processing Record 49 of Set 4 | haines junction
# Processing Record 50 of Set 4 | santa cruz del sur
# Processing Record 1 of Set 5 | sakakah
# Processing Record 2 of Set 5 | georgetown
# Processing Record 3 of Set 5 | college
# Processing Record 4 of Set 5 | ostrovnoy
# Processing Record 5 of Set 5 | vryburg
# Processing Record 6 of Set 5 | chapais
# Processing Record 7 of Set 5 | pangoa
# Processing Record 8 of Set 5 | gat
# Processing Record 9 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 5 | sao felix do xingu
# Processing Record 11 of Set 5 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 12 of Set 5 | riyadh
# Processing Record 13 of Set 5 | zaozerne
# Processing Record 14 of Set 5 | beringovskiy
# Processing Record 15 of Set 5 | flin flon
# Processing Record 16 of Set 5 | richards bay
# Processing Record 17 of Set 5 | anqing
# Processing Record 18 of Set 5 | omboue
# Processing Record 19 of Set 5 | puerto escondido
# Processing Record 20 of Set 5 | ljungby
# Processing Record 21 of Set 5 | sharjah
# Processing Record 22 of Set 5 | cap malheureux
# Processing Record 23 of Set 5 | khatanga
# Processing Record 24 of Set 5 | rach gia
# Processing Record 25 of Set 5 | sakete
# Processing Record 26 of Set 5 | okato
# Processing Record 27 of Set 5 | jimeta
# Processing Record 28 of Set 5 | verkhoyansk
# Processing Record 29 of Set 5 | matagami
# Processing Record 30 of Set 5 | shu
# Processing Record 31 of Set 5 | aquiraz
# Processing Record 32 of Set 5 | yangjiang
# Processing Record 33 of Set 5 | comodoro rivadavia
# Processing Record 34 of Set 5 | longyearbyen
# Processing Record 35 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 5 | faanui
# Processing Record 37 of Set 5 | luderitz
# Processing Record 38 of Set 5 | laguna
# Processing Record 39 of Set 5 | saint anthony
# Processing Record 40 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 5 | milkovo
# Processing Record 42 of Set 5 | villefranche-de-rouergue
# Processing Record 43 of Set 5 | safwah
# City not found. Skipping...
# Processing Record 44 of Set 5 | dikson
# Processing Record 45 of Set 5 | wufeng
# Processing Record 46 of Set 5 | saurimo
# Processing Record 47 of Set 5 | tuatapere
# Processing Record 48 of Set 5 | mount isa
# Processing Record 49 of Set 5 | siverek
# Processing Record 50 of Set 5 | rio brilhante
# Processing Record 1 of Set 6 | bethel
# Processing Record 2 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 3 of Set 6 | bambous virieux
# Processing Record 4 of Set 6 | provideniya
# Processing Record 5 of Set 6 | mancio lima
# Processing Record 6 of Set 6 | mweka
# Processing Record 7 of Set 6 | skara
# Processing Record 8 of Set 6 | cadillac
# Processing Record 9 of Set 6 | malinovskiy
# Processing Record 10 of Set 6 | ozernovskiy
# Processing Record 11 of Set 6 | bontang
# Processing Record 12 of Set 6 | poum
# Processing Record 13 of Set 6 | ballina
# Processing Record 14 of Set 6 | isangel
# Processing Record 15 of Set 6 | tromso
# Processing Record 16 of Set 6 | shelburne
# Processing Record 17 of Set 6 | jawhar
# Processing Record 18 of Set 6 | lewisporte
# Processing Record 19 of Set 6 | burgeo
# Processing Record 20 of Set 6 | cockburn town
# Processing Record 21 of Set 6 | chara
# Processing Record 22 of Set 6 | cotonou
# Processing Record 23 of Set 6 | caohai
# Processing Record 24 of Set 6 | mecca
# Processing Record 25 of Set 6 | bosaso
# Processing Record 26 of Set 6 | toora-khem
# Processing Record 27 of Set 6 | astoria
# Processing Record 28 of Set 6 | ossora
# Processing Record 29 of Set 6 | flinders
# Processing Record 30 of Set 6 | kaitangata
# Processing Record 31 of Set 6 | khani
# Processing Record 32 of Set 6 | asau
# Processing Record 33 of Set 6 | airai
# Processing Record 34 of Set 6 | bathsheba
# Processing Record 35 of Set 6 | verkhnyaya toyma
# Processing Record 36 of Set 6 | hofn
# Processing Record 37 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 38 of Set 6 | biak
# Processing Record 39 of Set 6 | krasnoselkup
# Processing Record 40 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 41 of Set 6 | colonia
# Processing Record 42 of Set 6 | golden
# Processing Record 43 of Set 6 | hambantota
# Processing Record 44 of Set 6 | tisovec
# Processing Record 45 of Set 6 | hay river
# Processing Record 46 of Set 6 | vaitape
# Processing Record 47 of Set 6 | rio gallegos
# Processing Record 48 of Set 6 | deputatskiy
# Processing Record 49 of Set 6 | la ronge
# Processing Record 50 of Set 6 | havoysund
# Processing Record 1 of Set 7 | george town
# Processing Record 2 of Set 7 | kutum
# Processing Record 3 of Set 7 | samarkand
# Processing Record 4 of Set 7 | bijie
# Processing Record 5 of Set 7 | rochegda
# Processing Record 6 of Set 7 | muros
# Processing Record 7 of Set 7 | buchanan
# Processing Record 8 of Set 7 | sioux lookout
# Processing Record 9 of Set 7 | trelew
# Processing Record 10 of Set 7 | jalingo
# Processing Record 11 of Set 7 | nsanje
# Processing Record 12 of Set 7 | kruisfontein
# Processing Record 13 of Set 7 | bonnyville
# Processing Record 14 of Set 7 | sergeyevka
# Processing Record 15 of Set 7 | pakwach
# City not found. Skipping...
# Processing Record 16 of Set 7 | dingle
# Processing Record 17 of Set 7 | north bend
# Processing Record 18 of Set 7 | sumbawa
# City not found. Skipping...
# Processing Record 19 of Set 7 | bad oldesloe
# Processing Record 20 of Set 7 | saint-leu
# Processing Record 21 of Set 7 | manicore
# Processing Record 22 of Set 7 | hamilton
# Processing Record 23 of Set 7 | baoying
# Processing Record 24 of Set 7 | salym
# Processing Record 25 of Set 7 | saint-augustin
# Processing Record 26 of Set 7 | wanning
# Processing Record 27 of Set 7 | adrasmon
# Processing Record 28 of Set 7 | mayo
# Processing Record 29 of Set 7 | sorong
# Processing Record 30 of Set 7 | vila franca do campo
# Processing Record 31 of Set 7 | mugur-aksy
# Processing Record 32 of Set 7 | panaba
# Processing Record 33 of Set 7 | balikpapan
# Processing Record 34 of Set 7 | esperance
# Processing Record 35 of Set 7 | floro
# Processing Record 36 of Set 7 | guerrero negro
# Processing Record 37 of Set 7 | namibe
# Processing Record 38 of Set 7 | mahebourg
# Processing Record 39 of Set 7 | surok
# Processing Record 40 of Set 7 | harer
# Processing Record 41 of Set 7 | skagastrond
# City not found. Skipping...
# Processing Record 42 of Set 7 | kitimat
# Processing Record 43 of Set 7 | along
# Processing Record 44 of Set 7 | jacmel
# Processing Record 45 of Set 7 | pula
# Processing Record 46 of Set 7 | seddon
# Processing Record 47 of Set 7 | acapulco
# Processing Record 48 of Set 7 | stralsund
# Processing Record 49 of Set 7 | alta floresta
# Processing Record 50 of Set 7 | nishihara
# Processing Record 1 of Set 8 | thabazimbi
# Processing Record 2 of Set 8 | poltavka
# Processing Record 3 of Set 8 | zawadzkie
# Processing Record 4 of Set 8 | te anau
# Processing Record 5 of Set 8 | cradock
# Processing Record 6 of Set 8 | san patricio
# Processing Record 7 of Set 8 | mahibadhoo
# Processing Record 8 of Set 8 | davila
# Processing Record 9 of Set 8 | viedma
# Processing Record 10 of Set 8 | kajiado
# Processing Record 11 of Set 8 | yishui
# Processing Record 12 of Set 8 | malanville
# Processing Record 13 of Set 8 | wawa
# Processing Record 14 of Set 8 | chambas
# Processing Record 15 of Set 8 | tucurui
# Processing Record 16 of Set 8 | del rio
# Processing Record 17 of Set 8 | ponta delgada
# Processing Record 18 of Set 8 | tres lagoas
# Processing Record 19 of Set 8 | bara
# Processing Record 20 of Set 8 | la arena
# Processing Record 21 of Set 8 | hun
# Processing Record 22 of Set 8 | bida
# Processing Record 23 of Set 8 | adrar
# Processing Record 24 of Set 8 | yuancheng
# Processing Record 25 of Set 8 | evensk
# Processing Record 26 of Set 8 | iquique
# Processing Record 27 of Set 8 | dharchula
# Processing Record 28 of Set 8 | murgab
# Processing Record 29 of Set 8 | prince rupert
# Processing Record 30 of Set 8 | alice springs
# Processing Record 31 of Set 8 | nantucket
# Processing Record 32 of Set 8 | hovd
# Processing Record 33 of Set 8 | qui nhon
# Processing Record 34 of Set 8 | kirakira
# Processing Record 35 of Set 8 | buariki
# City not found. Skipping...
# Processing Record 36 of Set 8 | hasaki
# Processing Record 37 of Set 8 | belaya gora
# Processing Record 38 of Set 8 | ust-uda
# Processing Record 39 of Set 8 | barcelona
# Processing Record 40 of Set 8 | palomares
# Processing Record 41 of Set 8 | le port
# Processing Record 42 of Set 8 | sabalgarh
# Processing Record 43 of Set 8 | finschhafen
# Processing Record 44 of Set 8 | soe
# Processing Record 45 of Set 8 | balkanabat
# Processing Record 46 of Set 8 | sovetskoye
# Processing Record 47 of Set 8 | camana
# Processing Record 48 of Set 8 | finote selam
# Processing Record 49 of Set 8 | portland
# Processing Record 50 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 1 of Set 9 | portobelo
# Processing Record 2 of Set 9 | nizwa
# Processing Record 3 of Set 9 | conde
# Processing Record 4 of Set 9 | carutapera
# Processing Record 5 of Set 9 | kisangani
# Processing Record 6 of Set 9 | santa lucia
# Processing Record 7 of Set 9 | karakendzha
# City not found. Skipping...
# Processing Record 8 of Set 9 | tautira
# Processing Record 9 of Set 9 | kavaratti
# Processing Record 10 of Set 9 | lasa
# Processing Record 11 of Set 9 | lavumisa
# Processing Record 12 of Set 9 | ndele
# Processing Record 13 of Set 9 | mokrousovo
# Processing Record 14 of Set 9 | siguiri
# Processing Record 15 of Set 9 | hualmay
# Processing Record 16 of Set 9 | yinchuan
# Processing Record 17 of Set 9 | san jose de sisa
# Processing Record 18 of Set 9 | mehamn
# Processing Record 19 of Set 9 | lorengau
# Processing Record 20 of Set 9 | bay roberts
# Processing Record 21 of Set 9 | lagoa
# Processing Record 22 of Set 9 | laredo
# Processing Record 23 of Set 9 | pontes e lacerda
# Processing Record 24 of Set 9 | wageningen
# Processing Record 25 of Set 9 | requena
# Processing Record 26 of Set 9 | washougal
# Processing Record 27 of Set 9 | ca mau
# Processing Record 28 of Set 9 | takoradi
# Processing Record 29 of Set 9 | el angel
# Processing Record 30 of Set 9 | paamiut
# Processing Record 31 of Set 9 | miranorte
# City not found. Skipping...
# Processing Record 32 of Set 9 | zabid
# Processing Record 33 of Set 9 | oksfjord
# Processing Record 34 of Set 9 | half moon bay
# Processing Record 35 of Set 9 | magole
# Processing Record 36 of Set 9 | alekseyevka
# Processing Record 37 of Set 9 | komsomolskiy
# Processing Record 38 of Set 9 | krutikha
# Processing Record 39 of Set 9 | atbasar
# Processing Record 40 of Set 9 | meulaboh
# Processing Record 41 of Set 9 | hirara
# Processing Record 42 of Set 9 | drumheller
# Processing Record 43 of Set 9 | broome
# Processing Record 44 of Set 9 | antananarivo
# Processing Record 45 of Set 9 | kangaatsiaq
# Processing Record 46 of Set 9 | bucerias
# Processing Record 47 of Set 9 | zhigansk
# Processing Record 48 of Set 9 | steamboat springs
# Processing Record 49 of Set 9 | goderich
# Processing Record 50 of Set 9 | karratha
# Processing Record 1 of Set 10 | calamar
# Processing Record 2 of Set 10 | pochutla
# Processing Record 3 of Set 10 | vestmannaeyjar
# Processing Record 4 of Set 10 | pergamino
# Processing Record 5 of Set 10 | launceston
# Processing Record 6 of Set 10 | acari
# Processing Record 7 of Set 10 | ventspils
# Processing Record 8 of Set 10 | talawdi
# City not found. Skipping...
# Processing Record 9 of Set 10 | nagua
# Processing Record 10 of Set 10 | egvekinot
# Processing Record 11 of Set 10 | necochea
# Processing Record 12 of Set 10 | yumen
# Processing Record 13 of Set 10 | bang saphan
# Processing Record 14 of Set 10 | sitka
# Processing Record 15 of Set 10 | taltal
# Processing Record 16 of Set 10 | okhotsk
# Processing Record 17 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 18 of Set 10 | zhaotong
# Processing Record 19 of Set 10 | kawalu
# Processing Record 20 of Set 10 | miquelon
# Processing Record 21 of Set 10 | rawson
# Processing Record 22 of Set 10 | chepareria
# Processing Record 23 of Set 10 | hokitika
# Processing Record 24 of Set 10 | siwan
# Processing Record 25 of Set 10 | tecoanapa
# Processing Record 26 of Set 10 | touros
# Processing Record 27 of Set 10 | nelson bay
# Processing Record 28 of Set 10 | tomatlan
# Processing Record 29 of Set 10 | orange cove
# Processing Record 30 of Set 10 | sao raimundo nonato
# Processing Record 31 of Set 10 | amazar
# Processing Record 32 of Set 10 | troitskoye
# Processing Record 33 of Set 10 | bengkulu
# Processing Record 34 of Set 10 | smolensk
# Processing Record 35 of Set 10 | tutoia
# Processing Record 36 of Set 10 | lantawan
# Processing Record 37 of Set 10 | broken hill
# Processing Record 38 of Set 10 | ouargaye
# Processing Record 39 of Set 10 | mwinilunga
# Processing Record 40 of Set 10 | sechura
# Processing Record 41 of Set 10 | redmond
# Processing Record 42 of Set 10 | rio tercero
# Processing Record 43 of Set 10 | iqaluit
# Processing Record 44 of Set 10 | yulara
# Processing Record 45 of Set 10 | kemijarvi
# Processing Record 46 of Set 10 | kiruna
# Processing Record 47 of Set 10 | singaraja
# Processing Record 48 of Set 10 | tarakan
# Processing Record 49 of Set 10 | teya
# Processing Record 50 of Set 10 | mwingi
# Processing Record 1 of Set 11 | monmouth
# Processing Record 2 of Set 11 | aleksandrov gay
# Processing Record 3 of Set 11 | nioki
# Processing Record 4 of Set 11 | trincomalee
# Processing Record 5 of Set 11 | peniche
# Processing Record 6 of Set 11 | lagunas
# Processing Record 7 of Set 11 | weligama
# Processing Record 8 of Set 11 | manggar
# Processing Record 9 of Set 11 | gazi
# Processing Record 10 of Set 11 | meadow lake
# Processing Record 11 of Set 11 | pukhrayan
# Processing Record 12 of Set 11 | axim
# Processing Record 13 of Set 11 | khash
# Processing Record 14 of Set 11 | fomboni
# Processing Record 15 of Set 11 | praia da vitoria
# Processing Record 16 of Set 11 | saint-paul
# Processing Record 17 of Set 11 | barinas
# Processing Record 18 of Set 11 | sangar
# Processing Record 19 of Set 11 | ust-maya
# Processing Record 20 of Set 11 | stonewall
# Processing Record 21 of Set 11 | nizhnevartovsk
# Processing Record 22 of Set 11 | ilo
# Processing Record 23 of Set 11 | butler
# Processing Record 24 of Set 11 | bakchar
# Processing Record 25 of Set 11 | tevaitoa
# Processing Record 26 of Set 11 | awjilah
# Processing Record 27 of Set 11 | avallon
# Processing Record 28 of Set 11 | mykolayivka
# Processing Record 29 of Set 11 | chebenki
# Processing Record 30 of Set 11 | katete
# Processing Record 31 of Set 11 | dauphin
# Processing Record 32 of Set 11 | sabang
# Processing Record 33 of Set 11 | carndonagh
# Processing Record 34 of Set 11 | horsham
# Processing Record 35 of Set 11 | oranjemund
# Processing Record 36 of Set 11 | nsoko
# Processing Record 37 of Set 11 | elizabeth city
# Processing Record 38 of Set 11 | badulla
# Processing Record 39 of Set 11 | tazovskiy
# Processing Record 40 of Set 11 | independence
# Processing Record 41 of Set 11 | melsungen
# Processing Record 42 of Set 11 | gallup
# Processing Record 43 of Set 11 | kousseri
# Processing Record 44 of Set 11 | vetlanda
# Processing Record 45 of Set 11 | la paz
# Processing Record 46 of Set 11 | yerofey pavlovich
# Processing Record 47 of Set 11 | srednekolymsk
# Processing Record 48 of Set 11 | west bay
# Processing Record 49 of Set 11 | coos bay
# Processing Record 50 of Set 11 | okandja
# City not found. Skipping...
# Processing Record 1 of Set 12 | kingman
# Processing Record 2 of Set 12 | kot isa khan
# Processing Record 3 of Set 12 | bambanglipuro
# Processing Record 4 of Set 12 | pangody
# Processing Record 5 of Set 12 | togur
# Processing Record 6 of Set 12 | ugoofaaru
# Processing Record 7 of Set 12 | lalganj
# Processing Record 8 of Set 12 | sao sebastiao
# Processing Record 9 of Set 12 | saint-hyacinthe
# Processing Record 10 of Set 12 | kamariotissa
# Processing Record 11 of Set 12 | deep river
# Processing Record 12 of Set 12 | melnikovo
# Processing Record 13 of Set 12 | hailar
# Processing Record 14 of Set 12 | caravelas
# Processing Record 15 of Set 12 | guangshui
# Processing Record 16 of Set 12 | makati
# Processing Record 17 of Set 12 | alcudia
# Processing Record 18 of Set 12 | betare oya
# Processing Record 19 of Set 12 | bagdarin
# Processing Record 20 of Set 12 | kasane
# Processing Record 21 of Set 12 | pevek
# Processing Record 22 of Set 12 | genhe
# Processing Record 23 of Set 12 | tura
# Processing Record 24 of Set 12 | ahipara
# Processing Record 25 of Set 12 | alofi
# Processing Record 26 of Set 12 | nemuro
# Processing Record 27 of Set 12 | semnan
# Processing Record 28 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 29 of Set 12 | mayumba
# Processing Record 30 of Set 12 | golspie
# Processing Record 31 of Set 12 | jacksonville beach
# Processing Record 32 of Set 12 | eyl
# Processing Record 33 of Set 12 | sao joao da barra
# Processing Record 34 of Set 12 | birnin kebbi
# Processing Record 35 of Set 12 | panalingaan
# Processing Record 36 of Set 12 | antigonish
# Processing Record 37 of Set 12 | aykhal
# Processing Record 38 of Set 12 | uniara
# Processing Record 39 of Set 12 | hami
# Processing Record 40 of Set 12 | palmer
# Processing Record 41 of Set 12 | korla
# Processing Record 42 of Set 12 | vardo
# Processing Record 43 of Set 12 | erzin
# Processing Record 44 of Set 12 | ust-kuyga
# Processing Record 45 of Set 12 | darhan
# Processing Record 46 of Set 12 | pauini
# Processing Record 47 of Set 12 | najran
# Processing Record 48 of Set 12 | hvolsvollur
# Processing Record 49 of Set 12 | denpasar
# Processing Record 50 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 1 of Set 13 | bennettsville
# Processing Record 2 of Set 13 | honghu
# Processing Record 3 of Set 13 | saint john
# Processing Record 4 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 13 | uspenka
# Processing Record 6 of Set 13 | martinsburg
# Processing Record 7 of Set 13 | chumikan
# Processing Record 8 of Set 13 | banda aceh
# Processing Record 9 of Set 13 | ukiah
# Processing Record 10 of Set 13 | erdenet
# Processing Record 11 of Set 13 | springbok
# Processing Record 12 of Set 13 | cayenne
# Processing Record 13 of Set 13 | manalongon
# Processing Record 14 of Set 13 | morondava
# Processing Record 15 of Set 13 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 13 | andenes
# Processing Record 17 of Set 13 | hattiesburg
# Processing Record 18 of Set 13 | stoyba
# City not found. Skipping...
# Processing Record 19 of Set 13 | marsa matruh
# Processing Record 20 of Set 13 | tessalit
# Processing Record 21 of Set 13 | dwarka
# Processing Record 22 of Set 13 | russell
# Processing Record 23 of Set 13 | ust-tsilma
# Processing Record 24 of Set 13 | bonfim
# Processing Record 25 of Set 13 | tubuala
# Processing Record 26 of Set 13 | katobu
# Processing Record 27 of Set 13 | luanshya
# Processing Record 28 of Set 13 | wonthaggi
# Processing Record 29 of Set 13 | lakewood
# Processing Record 30 of Set 13 | korsakov
# Processing Record 31 of Set 13 | pangkalanbuun
# Processing Record 32 of Set 13 | amambai
# Processing Record 33 of Set 13 | taoudenni
# Processing Record 34 of Set 13 | gamba
# Processing Record 35 of Set 13 | bordighera
# Processing Record 36 of Set 13 | ozgon
# City not found. Skipping...
# Processing Record 37 of Set 13 | kinsale
# Processing Record 38 of Set 13 | cabot
# Processing Record 39 of Set 13 | marigot
# Processing Record 40 of Set 13 | kattivakkam
# Processing Record 41 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 13 | iskandar
# Processing Record 43 of Set 13 | barra do garcas
# Processing Record 44 of Set 13 | japura
# Processing Record 45 of Set 13 | cozumel
# Processing Record 46 of Set 13 | gisborne
# Processing Record 47 of Set 13 | vrangel
# Processing Record 48 of Set 13 | arcata
# Processing Record 49 of Set 13 | vanimo
# Processing Record 50 of Set 13 | itarema
# Processing Record 1 of Set 14 | vidim
# Processing Record 2 of Set 14 | aklavik
# Processing Record 3 of Set 14 | west lafayette
# Processing Record 4 of Set 14 | burlington
# Processing Record 5 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 6 of Set 14 | uribia
# Processing Record 7 of Set 14 | quesnel
# Processing Record 8 of Set 14 | bardiyah
# Processing Record 9 of Set 14 | dubovskoye
# Processing Record 10 of Set 14 | siva
# Processing Record 11 of Set 14 | malanje
# Processing Record 12 of Set 14 | coracora
# Processing Record 13 of Set 14 | qafsah
# City not found. Skipping...
# Processing Record 14 of Set 14 | ahuimanu
# Processing Record 15 of Set 14 | ankang
# Processing Record 16 of Set 14 | mendi
# Processing Record 17 of Set 14 | channel-port aux basques
# Processing Record 18 of Set 14 | zamberk
# Processing Record 19 of Set 14 | gloversville
# Processing Record 20 of Set 14 | akhtubinsk
# Processing Record 21 of Set 14 | zlatoustovsk
# City not found. Skipping...
# Processing Record 22 of Set 14 | dubti
# Processing Record 23 of Set 14 | fairbanks
# Processing Record 24 of Set 14 | bowen
# Processing Record 25 of Set 14 | bilma
# Processing Record 26 of Set 14 | yacopi
# Processing Record 27 of Set 14 | arzgir
# Processing Record 28 of Set 14 | kropotkin
# Processing Record 29 of Set 14 | wembley
# Processing Record 30 of Set 14 | juba
# Processing Record 31 of Set 14 | uwayl
# City not found. Skipping...
# Processing Record 32 of Set 14 | dafeng
# Processing Record 33 of Set 14 | ziarat
# Processing Record 34 of Set 14 | moscow
# Processing Record 35 of Set 14 | qinhuangdao
# Processing Record 36 of Set 14 | formoso do araguaia
# City not found. Skipping...
# Processing Record 37 of Set 14 | raudeberg
# Processing Record 38 of Set 14 | krasnokamensk
# Processing Record 39 of Set 14 | coquimbo
# Processing Record 40 of Set 14 | otradnoye
# Processing Record 41 of Set 14 | jalalpur pirwala
# Processing Record 42 of Set 14 | the valley
# Processing Record 43 of Set 14 | coahuayana
# Processing Record 44 of Set 14 | boundiali
# Processing Record 45 of Set 14 | acarau
# Processing Record 46 of Set 14 | amot
# Processing Record 47 of Set 14 | letterkenny
# Processing Record 48 of Set 14 | bintulu
# Processing Record 49 of Set 14 | pontianak
# Processing Record 50 of Set 14 | saint-joseph
# Processing Record 1 of Set 15 | blairmore
# Processing Record 2 of Set 15 | vila do maio
# Processing Record 3 of Set 15 | mangan
# Processing Record 4 of Set 15 | qasigiannguit
# Processing Record 5 of Set 15 | gedo
# Processing Record 6 of Set 15 | shenkursk
# Processing Record 7 of Set 15 | ulladulla
# Processing Record 8 of Set 15 | olafsvik
# Processing Record 9 of Set 15 | tasbuget
# City not found. Skipping...
# Processing Record 10 of Set 15 | margate
# Processing Record 11 of Set 15 | nouakchott
# Processing Record 12 of Set 15 | kushima
# Processing Record 13 of Set 15 | makokou
# Processing Record 14 of Set 15 | tynda
# Processing Record 15 of Set 15 | lang son
# Processing Record 16 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 17 of Set 15 | kuytun
# Processing Record 18 of Set 15 | san cristobal
# Processing Record 19 of Set 15 | doha
# Processing Record 20 of Set 15 | chulym
# Processing Record 21 of Set 15 | kambam
# Processing Record 22 of Set 15 | san quintin
# Processing Record 23 of Set 15 | tukums
# Processing Record 24 of Set 15 | stuttgart
# Processing Record 25 of Set 15 | quatre cocos
# Processing Record 26 of Set 15 | bilibino
# Processing Record 27 of Set 15 | yeppoon
# Processing Record 28 of Set 15 | moose factory
# Processing Record 29 of Set 15 | lamesa
# Processing Record 30 of Set 15 | abonnema
# Processing Record 31 of Set 15 | pandan
# Processing Record 32 of Set 15 | ayolas
# Processing Record 33 of Set 15 | dzilam gonzalez
# Processing Record 34 of Set 15 | masindi
# Processing Record 35 of Set 15 | chiang klang
# Processing Record 36 of Set 15 | karasjok
# Processing Record 37 of Set 15 | kasongo-lunda
# Processing Record 38 of Set 15 | watsa
# Processing Record 39 of Set 15 | rincon
# Processing Record 40 of Set 15 | svetlogorsk
# Processing Record 41 of Set 15 | port macquarie
# Processing Record 42 of Set 15 | utiel
# Processing Record 43 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 44 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 45 of Set 15 | kytlym
# City not found. Skipping...
# Processing Record 46 of Set 15 | halacho
# Processing Record 47 of Set 15 | poplevinskiy
# Processing Record 48 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 49 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 50 of Set 15 | fort saint john
# City not found. Skipping...
# Processing Record 1 of Set 16 | ponta pora
# Processing Record 2 of Set 16 | andilamena
# Processing Record 3 of Set 16 | san andres
# Processing Record 4 of Set 16 | uren
# Processing Record 5 of Set 16 | inhambane
# Processing Record 6 of Set 16 | mashhad
# Processing Record 7 of Set 16 | niquero
# Processing Record 8 of Set 16 | shakiso
# Processing Record 9 of Set 16 | santa cruz
# Processing Record 10 of Set 16 | kaohsiung
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Punta Arenas      CL -53.1500  -70.9167    279.21        70          20
# 1        Castro      BR -24.7911  -50.0119    291.56        92          80
# 2        Torbay      CA  47.6666  -52.7314    276.80        81          40
# 3          Lebu      CL -37.6167  -73.6500    285.90        70           0
# 4        Atuona      PF  -9.8000 -139.0333    299.75        72          52
#
#    Wind Speed Weather Description
# 0       10.29          few clouds
# 1        2.18       broken clouds
# 2       14.40    scattered clouds
# 3        8.39           clear sky
# 4        9.59       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
